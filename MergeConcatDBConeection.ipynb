# %%
import pandas as pd

# %%
df1 = pd.read_csv('employees.csv')

# %% [markdown]
# df1

# %%
df1
# Out:
#    eno   ename
# 0    1   james
# 1    2   coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
df2 = pd.read_csv('salaries.csv')

# %%
df2
# Out:
#    eno  salaries
# 0    1      1000
# 1    2      2000
# 2    3      3000
# 3    6      6000
# 4    7      7000

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
#    eno   ename  salaries
# 0    1   james      1000
# 1    2   coles      2000
# 2    3  Thomas      3000

# %%
df1.merge(df2,on='eno',how='left')
# Out:
#    eno   ename  salaries
# 0    1   james    1000.0
# 1    2   coles    2000.0
# 2    3  Thomas    3000.0
# 3    4  Mayank       NaN
# 4    5   Akash       NaN

# %%
df1.merge(df2,on='eno',how='right')
# Out:
#    eno   ename  salaries
# 0    1   james      1000
# 1    2   coles      2000
# 2    3  Thomas      3000
# 3    6     NaN      6000
# 4    7     NaN      7000

# %%
df1.merge(df2,on='eno',how='outer')
# Out:
#    eno   ename  salaries
# 0    1   james    1000.0
# 1    2   coles    2000.0
# 2    3  Thomas    3000.0
# 3    4  Mayank       NaN
# 4    5   Akash       NaN
# 5    6     NaN    6000.0
# 6    7     NaN    7000.0

# %%
df1.dtypes
# Out:
# eno       int64
# ename    object
# dtype: object

# %%
df2.dtypes
# Out:
# eno         int64
# salaries    int64
# dtype: object

# %%
df3 = pd.read_csv('employees1.csv')

# %%
df3
# Out:
#    eno   ename
# 0    1   james
# 1    2   coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash
# 5    9  Pankaj
# 6   10  Rakesh
# 7   11  Thomas

# %%
result = pd.concat([df1,df3],axis=0)

# %%
result
# Out:
#    eno   ename
# 0    1   james
# 1    2   coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash
# 0    1   james
# 1    2   coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash
# 5    9  Pankaj
# 6   10  Rakesh
# 7   11  Thomas

# %%
# connect to mysql and read the data from table
import pandas as pd
from sqlalchemy import create_engine
mysql_engine = create_engine('mysql+pymysql://root:Admin%40143@localhost:3308/etlqalabsdb')
connection =mysql_engine.connect()
df = pd.read_sql("select * from employees",connection)

# %%
df
# Out:
#      id first_name  last_name                          email department  \
# 0     1       John        Doe           john.doe@example.com         HR
# 1     2       Jane      Smith         jane.smith@example.com    Finance
# 2     3    Michael      Brown      michael.brown@example.com         HR
# 3     4      Emily      Davis        emily.davis@example.com  Marketing
# 4     5      James     Wilson       james.wilson@example.com         IT
# 5     6      Linda      Jones        linda.jones@example.com         HR
# 6     7     Robert     Garcia      robert.garcia@example.com    Finance
# 7     8      Maria   Martinez     maria.martinez@example.com  Marketing
# 8     9    William  Hernandez  william.hernandez@example.com         IT
# 9    10      David      Lopez        david.lopez@example.com         HR
# 10   11      Sarah   Gonzalez     sarah.gonzalez@example.com         HR
# 11   12    Charles     Wilson     charles.wilson@example.com         HR
# ...

# %%
# connect to oracle and read the data from table
import pandas as pd
from sqlalchemy import create_engine
import cx_Oracle
oracle_engine = create_engine('oracle+cx_oracle://system:admin@localhost:1521/xe')
oracle_connection =oracle_engine.connect()
df = pd.read_sql("select * from city",oracle_connection)
df
# Out:
#     id       name
# 0    1      Delhi
# 1    2  Bangalore
# 2  100    Kolkata
# 3    3       Pune
# 4    4     Mumbai
# 5  101     Indore
# 6    8        Goa
# 7    9     Kanpur

# %%
mysql_engine = create_engine('mysql+pymysql://root:Admin%40143@localhost:3308/etlqalabsdb')
connection =mysql_engine.connect()
df = pd.read_sql("select * from employees",connection)
